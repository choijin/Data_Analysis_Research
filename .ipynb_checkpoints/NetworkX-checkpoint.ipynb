# %% [markdown]
# # NetworkX

# %%
import pandas as pd
import numpy as np
import networkx as nx
from networkx.algorithms import node_classification
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import dataframe from CSV

# %%
#Combined dataframe from years 2021 to 2011
df_main = pd.read_csv("csv_data/combined_2021_2011.csv")

#Dataframe of topic lists and frequencies
df_topics = pd.read_csv("csv_data/PhraseFrequency.csv", index_col=0)
topicList = df_topics['phrase'].tolist()

# Test run
df_2020 = pd.read_csv("csv_data/df_2020_filtered.csv")
df_2020_topics = pd.read_csv("csv_data/df_2020_topics.csv")

# %%
df_2020_topics
# Out:
#       Unnamed: 0                    phrase  frequency
# 0              0          machine learning        181
# 1              1          computer science        161
# 2              2             deep learning         56
# 3              3         covid-19 pandemic         54
# 4              4            edge computing         50
# ...          ...                       ...        ...
# 3277        3277  cryptography distributed          3
# 3278        3278  distributed cryptography          3
# 3279        3279                  uhf rfid          3
# 3280        3280                 rfid tags          3
# 3281        3281     authentication system          3
#
# [3282 rows x 3 columns]

# %% [markdown]
# ## Generate nodes of topic phrases

# %%
"""
Generate nodes, edges and the weight of frequency by counting the occurences 
of the topic lists in the main data, iterated row by row.
Args:
df - the main dataframe
phraseList - the list of phrases, or nodes we are working with
nodeNumber - number of nodes to generate. This number corresponds to the number of
             topic phrases we want to consider in the phraseList
"""
def node_generator(df, topicList, nodeNumber): 
    
    # Create an undirectional node graph
    G = nx.Graph()
    
    # Create a copy of df
    df1 = df.copy()
    
    # Create topicList with specified number equivalent to nodeNumber
    topicPhrase = topicList['phrase'][:nodeNumber]
    
    # Iterate through the top frequent words that we have generated previously
    for i in range(len(topicPhrase)):
        
        # Creating individual nodes with its frequency
        G.add_node(topicPhrase[i], weight=topicList['frequency'][i])
        
        for j in range(i + 1, len(topicPhrase)):
            count = 0
            # Iterate through dataframe
            for index, row in df1.iterrows():
                text_data = ('').join(row['abstract']) + ('').join(row['title'])
                # Since the file is reading in as string types, I want to remove ", and "'"
                text_data = text_data.replace(',', '').replace('[', '').replace(']', '').replace("'", "")
                if topicPhrase[i] in text_data and topicPhrase[j] in text_data:
                    count += 1
                    
            # If there was an occurance of two topics
            if (count > 0):
                G.add_edge(topicPhrase[i], topicPhrase[j], weight=count)
        
    return G

# %% [markdown]
# ## Graph NetworkX

# %%
def graph_networkX(G):
    # Create positions of all nodes and save them
    pos = nx.spring_layout(G)

    # Draw the graph according to node positions
    nx.draw(G, pos, with_labels=True)

    # Create edge labels
    labels = {e: G.edges[e]['weight'] for e in G.edges}

    # Draw edge labels according to node positions
    nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

# %% [markdown]
# ### Testing with data from 2020

# %%
# Using 10 topic lists
G_2020 = node_generator(df_2020, df_2020_topics, 10)
# G_2020.edges(data=True)

# %%
nx.pagerank(G_2020)
# Out:
# {'machine learning': 0.2547209648644971,
#  'computer science': 0.0691283362504466,
#  'deep learning': 0.11214974452290022,
#  'covid-19 pandemic': 0.05716540183563763,
#  'edge computing': 0.06818123547062672,
#  'wireless networks': 0.09236014021610728,
#  'artificial intelligence': 0.1353541095336169,
#  'reinforcement learning': 0.10083061950958351,
#  'iot devices': 0.06221373465149535,
#  'social media': 0.0478957131450886}

# %%
plt.rcParams['figure.figsize'] = [30,25]
graph_networkX(G_2020)

# %%
# Using 300 topic list 
# Took 1.5 hrs...
G1_2020 = node_generator(df_2020, df_2020_topics, 300)

# %%
G1_2020.edges(data=True)
# Out:
# EdgeDataView([('machine learning', 'computer science', {'weight': 8}), ('machine learning', 'deep learning', {'weight': 15}), ('machine learning', 'covid-19 pandemic', {'weight': 3}), ('machine learning', 'edge computing', {'weight': 9}), ('machine learning', 'wireless networks', {'weight': 11}), ('machine learning', 'artificial intelligence', {'weight': 18}), ('machine learning', 'reinforcement learning', {'weight': 10}), ('machine learning', 'iot devices', {'weight': 8}), ('machine learning', 'social media', {'weight': 4}), ('machine learning', 'underrepresented groups', {'weight': 8}), ('machine learning', 'public health', {'weight': 3}), ('machine learning', 'cloud computing', {'weight': 8}), ('machine learning', 'learning techniques', {'weight': 19}), ('machine learning', 'internet things', {'weight': 10}), ('machine learning', 'cyber-physical systems', {'weight': 7}), ('machine learning', 'data analytics', {'weight': 8}), ('machine learning', 'edge devices', {'weight': 6}), ('machine learning', 'learning algorithms', {'weight': 17}), ('machine learning', 'big data', {'weight': 4}), ('machine learning', 'computer information', {'weight': 1}), ('machine learning', 'wireless network', {'weight': 14}), ('machine learning', 'science engineering', {'weight': 7}), ('machine learning', 'securitybrbrthis foundations', {'weight': 1}), ('machine learning', 'natural disasters', {'weight': 1}), ('machine learning', 'civic program', {'weight': 1}), ('machine learning', 'computing systems', {'weight': 3}), ('machine learning', 'data center', {'weight': 3}), ('machine learning', 'open source', {'weight': 4}), ('machine learning', 'decision making', {'weight': 7}), ('machine learning', 'data collected', {'weight': 5}), ('machine learning', 'things iot', {'weight': 9}), ('machine learning', 'differential privacy', {'weight': 2}), ('machine learning', 'wireless edge', {'weight': 5}), ('machine learning', 'data collection', {'weight': 2}), ('machine learning', 'homeland securitybrbrthis', {'weight': 1}), ('machine learning', 'techniques developed', {'weight': 5}), ('machine learning', 'storage systems', {'weight': 1}), ('machine learning', 'underrepresented students', {'weight': 2}), ('machine learning', 'students underrepresented', {'weight': 2}), ('machine learning', 'intelligence ai', {'weight': 7}), ('machine learning', 'data science', {'weight': 8}), ('machine learning', 'security privacy', {'weight': 7}), ('machine learning', 'outreach activities', {'weight': 5}), ('machine learning', 'georgia tech', {'weight': 1}), ('machine learning', 'systems cps', {'weight': 5}), ('machine learning', 'neural network', {'weight': 16}), ('machine learning', 'mobile devices', {'weight': 3}), ('machine learning', 'information theory', {'weight': 3}), ('machine learning', 'source code', {'weight': 9}), ('machine learning', 'access control', {'weight': 3}), ('machine learning', 'quality life', {'weight': 6}), ('machine learning', 'mobile edge', {'weight': 2}), ('machine learning', 'widely used', {'weight': 3}), ('machine learning', 'data generated', {'weight': 5}), ('machine learning', 'energy consumption', {'weight': 6}), ('machine learning', 'address challenges', {'weight': 6}), ('machine learning', 'proposed work', {'weight': 3}), ('machine learning', 'fake news', {'weight': 1}), ('machine learning', 'sensor data', {'weight': 1}), ('machine learning', 'information science', {'weight': 1}), ('machine learning', 'data sets', {'weight': 3}), ('machine learning', 'iot systems', {'weight': 2}), ('machine learning', 'iot applications', {'weight': 3}), ('machine learning', 'deep neural', {'weight': 10}), ('machine learning', 'neural networks', {'weight': 10}), ('machine learning', 'internet-of-things iot', {'weight': 5}), ('machine learning', 'data analysis', {'weight': 2}), ('machine learning', 'autonomous vehicles', {'weight': 5}), ('machine learning', 'real time', {'weight': 4}), ('machine learning', 'resource management', {'weight': 1}), ('machine learn ...

# %%
nx.pagerank(G1_2020)
# Out:
# {'machine learning': 0.023713308843125412,
#  'computer science': 0.01286021049747699,
#  'deep learning': 0.008321047542602954,
#  'covid-19 pandemic': 0.007377188805262914,
#  'edge computing': 0.006257023853065386,
#  'wireless networks': 0.008180005205607611,
#  'artificial intelligence': 0.010769203931452078,
#  'reinforcement learning': 0.006633298309800529,
#  'iot devices': 0.0076092163679093465,
#  'social media': 0.0027527862204767355,
#  'underrepresented groups': 0.009758887483411634,
#  'public health': 0.005260966805821124,
#  'cloud computing': 0.0054683919692828965,
#  'learning techniques': 0.007131283761531179,
#  'internet things': 0.009355822121425248,
#  'cyber-physical systems': 0.005523367971302397,
#  'data analytics': 0.00588557360681374,
#  'edge devices': 0.004235320741476775,
#  'learning algorithms': 0.005896631869414407,
#  'big data': 0.004197929245220132,
#  'computer information': 0.001323741546711047,
#  'wireless network': 0.010389292233718596,
#  'science engineering': 0.005223189176749759,
#  'securitybrbrthis foundations': 0.007553339721067145,
#  'natural disasters': 0.0063283929846175285,
#  'civic program': 0.00834593934734787,
#  'computing systems': 0.004607870387629914,
#  'data center': 0.0025700707769748254,
#  'open source': 0.004597465833502938,
#  'decision making': 0.005597493404096912,
#  'data collected': 0.004479391843277513,
#  'things iot': 0.01044253293854446,
#  'differential privacy': 0.0040142375568813565,
#  'wireless edge': 0.004280445162349172,
#  'data collection': 0.004434749307997871,
#  'homeland securitybrbrthis': 0.006232174682689809,
#  'techniques developed': 0.005217152319354669,
#  'storage systems': 0.0016185143406023945,
#  'underrepresented students': 0.004932724792374133,
#  'students underrepresented': 0.005770546258568957,
#  'intelligence ai': 0.005543975780352049,
#  'data science': 0.0033210671135300556,
#  'security privacy': 0.003681063471889722,
#  'outreach activities': 0.005813170526133312,
#  'georgia tech': 0.0019086038280677698,
#  'systems cps': 0.0037413269229657742,
#  'neural network': 0.008899440224370746,
#  'mobile devices': 0.003278282346563538,
#  'information theory': 0.002097366214318507,
#  'source code': 0.005555985263815806,
#  'access control': 0.0032634566237511506,
#  'quality life': 0.003344278330369511,
#  'mobile edge': 0.002921790960107808,
#  'widely used': 0.002681191858776014,
#  'data generated': 0.004109894013248112,
#  'energy consumption': 0.003976103909942996,
#  'address challenges': 0.004437696744246839,
#  'proposed work': 0.0029686958567587195,
#  'fake news': 0.0009785212179379864,
#  'sensor data': 0.0015484648491372144,
#  'information science': 0.001993964332842983,
#  'data sets': 0.0021723367795624757,
#  'iot systems': 0.003628280225558002,
#  'iot applications': 0.0048699698028182485,
#  'deep neural': 0.004950116373141872,
#  'neural networks': 0.005711242514129869,
#  'internet-of-things iot': 0.004612080644164644,
#  'data analysis': 0.004152489484368874,
#  'autonomous vehicles': 0.00324675037189836,
#  'real time': 0.003157226884723489,
#  'resource management': 0.0026782661214667857,
#  'thrusts first': 0.004056790490055258,
#  'unmanned aerial': 0.003121986238033205,
#  'learning models': 0.003106315160112971,
#  'response civic': 0.005627924511018043,
#  'service providers': 0.0029135114026162196,
#  'include 1': 0.0028480791226110982,
#  'smart cities': 0.0021791254822175676,
#  'learning systems': 0.004010126042884202,
#  'science education': 0.003960209941134821,
#  'deep reinforcement': 0.003678036777359006,
#  'second thrust': 0.0035966055407252407,
#  'aerial vehicles': 0.003324118976088319,
#  'computing resources': 0.002300164696556115,
#  'network traffic': 0.0021992322865963558,
#  'control algorithms': 0.0023288677342552288,
#  'community members': 0.0028157140025614233,
#  'tools developed': 0.0029720855941122227,
#  'embedded systems': 0.0026671056927223312,
#  'software tools': 0.002594302379254655,
#  'federated learning': 0.0028986901285511374,
#  'distributed learning': 0.003028385776127187,
#  'technology transfer': 0.003936523445073687,
#  'academia industry': 0.004082569205514458,
#  'design implement': 0.0040485438356083385,
#  'resource allocation': 0.0043222074989282665,
#  'science technology': 0.0029116737375480053,
#  'computer systems': 0.001955901429834366,
#  'education outreach': 0.0036818977822493573,
#  'advance understanding': 0.0027258047562536887,
#  'government agencies': 0.0025941448815045174,
#  'data sharing': 0.0029131986736119376,
#  'emergency response': 0.0026011481757849016,
#  'real-time systems': 0.002093762526569506,
#  'web applications': 0.0009370417595692175,
#  'information technology': 0.0015265470905460924,
#  'operating system': 0.0031369769857270253,
#  'opportunities students': 0.0031134269481009553,
#  'learning ml': 0.0035587608683545578,
#  'data privacy': 0.0030726086147830835,
#  'team develop': 0.003920224002774055,
#  'develop techniques': 0.0028057729843805096,
#  'wireless networking': 0.0028930734067286116,
#  'goal develop': 0.003442422941363755,
#  'online learning': 0.002741730290150142,
#  'rural areas': 0.002762329370022173,
#  'distributed computing': 0.0022579403165364853,
#  'three main': 0.0034827343756388715,
#  'many applications': 0.0027845936045958644,
#  'projectbrbrthis foundations': 0.00320648322994887,
#  'three thrusts': 0.003189937974931081,
#  'computing system': 0.005572171653492598,
#  'dnn model': 0.0011461372972771532,
#  'smart connected': 0.0029473282893022696,
#  'smart grid': 0.0022793837203126327,
#  'learning control': 0.0013525535661236883,
#  'proposed techniques': 0.0029331010823654496,
#  '2 develop': 0.005000856573731213,
#  'three years': 0.0037546021168076123,
#  'brbrthe proposed': 0.00670960545391474,
#  'drug discovery': 0.0014054417003022289,
#  'quantum computing': 0.0014961096329901445,
#  'techniques tools': 0.0021306648077628323,
#  'private data': 0.0018757460416080527,
#  'social distancing': 0.002205240576145857,
#  'disaster management': 0.0023164021141798383,
#  'processing units': 0.0025691006290527105,
#  'distributed machine': 0.004518198022816349,
#  'signal processing': 0.002359282331118237,
#  'minority students': 0.0038109848207107965,
#  'autonomous driving': 0.003431331439839023,
#  'computer vision': 0.0029689036322334333,
#  'long term': 0.002557614291772328,
#  'outreach efforts': 0.0027879957343630917,
#  'five years': 0.0031363367231486117,
#  'virtual reality': 0.0033593202369483826,
#  'take advantage': 0.0027689344003299235,
#  'education development': 0.0033000857140445482,
#  'extreme mobility': 0.0009968557458897853,
#  'collected data': 0.0034428651238785895,
#  'hardware design': 0.002114855945520578,
#  'formal verification': 0.0016161576895006116,
#  'stem education': 0.0026886613796214594,
#  'end users': 0.0025070123908913396,
#  'personal information': 0.0018149717712511288,
#  'response covid-19': 0.0031526357122889457,
#  'mitigation strategies': 0.0018387596714355072,
#  'resilience natural': 0.005674934796949062,
#  'data management': 0.001913299305201659,
#  'applications smart': 0.0032512952672765862,
#  'integrated education': 0.004588767619372764,
#  'industrial automation': 0.00153160888186282,
#  'underrepresented minority': 0.0033279025177483535,
#  'recent years': 0.0024302749232558217,
#  'design implementation': 0.0026309528159874193,
#  'network edge': 0.0032024174244021115,
#  'objective develop': 0.002596158366803186,
#  'wireless channel': 0.002780375404197451,
#  'amounts data': 0.0024192441162274483,
#  'internet service': 0.001696313645481313,
#  'techniques enable': 0.0028440715900084333,
#  'network resources': 0.0027916738603265723,
#  'significantly reduce': 0.0031377512636777617,
#  'distributed systems': 0.0021222047192621103,
#  'students especially': 0.004127907889452451,
#  'educational activities': 0.0024853699036289038,
#  'proposed framework': 0.0019260186570372907,
#  'tools techniques': 0.002397808304049715,
#  'engage students': 0.0037546562307535407,
#  'data sources': 0.0018225984729301242,
#  'significantly advance': 0.003033455067752226,
#  'risk factors': 0.0018991742885284997,
#  'better understand': 0.003519328401031228,
#  'north carolina': 0.002174846884504619,
#  'augmented reality': 0.0034167686542668683,
#  'transportation systems': 0.002072284897584567,
#  'collect data': 0.0032203319319059694,
#  'serverless functions': 0.0011382445963901118,
#  'intrusion detection': 0.0017514264566153874,
#  'latinx students': 0.0010874236360072127,
#  'privacy protection': 0.0021148480306925218,
#  'differentially private': 0.0017275076014665342,
#  'community partners': 0.0029430396784397694,
#  '1 design': 0.004162994147985806,
#  'physical computing': 0.0017730996702348145,
#  'program b—resilience': 0.0037696222957124335,
#  'b—resilience natural': 0.0037696222957124335,
#  'natural disasters—and': 0.0037696222957124335,
#  'disasters—and homeland': 0.0037696222957124335,
#  'power grid': 0.0018529547260937237,
#  'design development': 0.0026369157040060285,
#  'control theory': 0.0022672231155626403,
#  'goals 1': 0.002461061815111758,
#  'large-scale wireless': 0.0014764209422853064,
#  'learning methods': 0.0027388646980466592,
#  'low cost': 0.0024223624613338617,
#  'learning framework': 0.004285019247260571,
#  'wireless communication': 0.0027414468412592305,
#  'future wireless': 0.0025418509306709613,
#  'develop innovative': 0.0023076140462890806,
#  'iot data': 0.0033067307873524917,
#  'adversarial attacks': 0.0022137969802518247,
#  'privacy security': 0.002369594661186469,
#  'bridge gap': 0.002836147401232274,
#  'wireless sensing': 0.0013137700638232049,
#  'systems including': 0.002454841873946287,
#  'advance state-of-the-art': 0.0023697790384515065,
#  'video analytics': 0.0009244180110310227,
#  'disaster response': 0.0024930182171858323,
#  '5 years': 0.002745152187585245,
#  'modeling analysis': 0.0018370135195148792,
#  'computing infrastructure': 0.002234047348468094,
#  'anomaly detection': 0.0016135478242764768,
#  'tools enable': 0.0022204162894099103,
#  'systems design': 0.003134349807843332,
#  'information freshness': 0.0010024418050328262,
#  'analysis techniques': 0.0032314125426662647,
#  'serverless computing': 0.00166715459716494,
#  'however existing': 0.002812699743070885,
#  'spatial mismatch': 0.00565934320250662,
#  'remote learning': 0.0022920037991594057,
#  'mobility options': 0.005449055231828764,
#  'mismatch housing': 0.005391737258954219,
#  'housing affordability': 0.005449055231828764,
#  'information sciences': 0.0012329597055242647,
#  'science cs': 0.002895947410692407,
#  'community resilience': 0.003975136432185598,
#  'options solve': 0.0051814413339870795,
#  'cs courses': 0.002333783641174513,
#  'cs educators': 0.001115916840317793,
#  'mobility offering': 0.0051814413339870795,
#  'offering better': 0.0051814413339870795,
#  'better mobility': 0.0051814413339870795,
#  'solve spatial': 0.0051814413339870795,
#  'tools help': 0.0027076097545407386,
#  'first thrust': 0.0033118817456624697,
#  'african americans': 0.001272755341234181,
#  'cs education': 0.0023423280046175653,
#  'cs teachers': 0.003101433156951238,
#  'public schools': 0.002283597777118182,
#  'civic -': 0.002827965422046028,
#  'projects novelties': 0.001533129319546172,
#  'experienced ecs': 0.0011927837187126512,
#  'ecs teachers': 0.002142048308932443,
#  'partnership rpp': 0.0017013237309994721,
#  'energybrbrthis foundations': 0.003068589661282054,
#  'affordability jobs': 0.0051814413339870795,
#  'climate change': 0.002039175261780562,
#  'center networks': 0.001444042188873766,
#  'third thrust': 0.002741643774893526,
#  'students computer': 0.0025246541257266586,
#  'medical devices': 0.0011004292835308923,
#  'exploring computer': 0.002594566833801957,
#  'science ecs': 0.002594566833801957,
#  'supported civic': 0.0034107736682961877,
#  'teaching materials': 0.0023934886283221222,
#  'least five': 0.002692813295893581,
#  'stream processing': 0.0008511433054085929,
#  'questions 1': 0.0028571954788642077,
#  'spread covid-19': 0.0017811820193526623,
#  'repository maintained': 0.0028583010456348333,
#  'system architecture': 0.001924147095624773,
#  'training students': 0.0021192743058657693,
#  'contact tracing': 0.001415091340973796,
#  'community engagement': 0.004102048932238505,
#  'stage 2': 0.0029021696133077466,
#  'xr technologies': 0.0012314208772611912,
#  'internet access': 0.002058067953842018,
#  'public transit': 0.0024406207536212025,
#  'spread virus': 0.0010805898976465433,
#  'data structures': 0.0012690698495747426,
#  'advance knowledge': 0.0025181892980091513,
#  'computer security': 0.0012973387005308348,
#  'cyber sexual': 0.0006013878791288994,
#  'privacy concerns': 0.002330158580669433,
#  'develop tools': 0.002455134718394302,
#  'linux kernel': 0.000965252140737847,
#  'wireless xr': 0.0009185946670251341,
#  'affordable housing': 0.0034801546553140435,
#  'cloud storage': 0.0016829031877563122,
#  'smart city': 0.0034495166197584487,
#  'population health': 0.0010039946776590584,
#  'healthcare elderly': 0.0016559516769845584,
#  'elderly care': 0.0016559516769845584,
#  'iot hardware': 0.0016559516769845584,
#  'privacy preserving': 0.0013471521293791312,
#  'disaster resilience': 0.002453124489202843,
#  'data analyses': 0.0012555474751260675,
#  'lattice-based cryptography': 0.000714433585263954,
#  'foundations recent': 0.0005014206919605551}

# %%
plt.rcParams['figure.figsize'] = [100,80]
graph_networkX(G1_2020)

# %% [markdown]
# ### Using the entire dataset from 2011 to 2021

# %%
G_total = node_generator(df_main, topicList, 20)

# %%
graph_networkX(G_total)
